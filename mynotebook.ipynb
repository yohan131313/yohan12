# %% [markdown]
# 중요한 코드나 문서를 함께 작성할거에요
# 작성일: 2026.09.08
# 작성자: 남요한

# %%
print("Hello world")
x=3
print("x=",x)
# Out:
# Hello world
# x= 3

# %% [markdown]
# 이 알고리즘은 아주 간닿바니다.
# 백트래킹 알고리즘을 사용허였으며, DFS 기법을 사용하였습니다.
